# %%
from session_handler import *
#from counter import Counter
from datetime import time as dtime
from datetime import date,datetime,timedelta
from klse_scrapper import *
from shareinvestor_scrapper import *

# %%
generate_session()

# %%
harta=Counter(symbol='HARTA',counter='5168',scheduler_on=True)
topglov=Counter(symbol='TOPGLOV',counter='7081',scheduler_on=True)
#supermx=Counter(symbol='SUPERMX',counter='7106',scheduler_on=True)

# %%
tomorrow=date.today()+ timedelta(days=1)
datetime.combine(tomorrow, dtime(9)).timestamp()

# %%
#test case for mine price data
session=read_session()
category='Health Care'
tomorrow=date.today()+ timedelta(days=1)
to_=datetime.combine(tomorrow, dtime(9)).timestamp()
yesterday=date.today() + timedelta(days=-3)
from_=datetime.combine(yesterday, dtime(9)).timestamp()
#mine_price_data('Main Market',category,'1m',from_,to_)
# %time mine_quote_movements(session=session,board='Main Market',category=category,from_=from_,to_=to_)
# Out:
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# "None of ['time'] are in the columns"
# "None of ['time'] are in the columns"
# CSV exists. Not going to crawl.
# CSV exists. Not going to crawl.
# Wall time: 31.3 s

# %%
session=read_session()


# %time mine_quote_movements(session=session,board='Main Market',category='Energy',from_=1592180738,to_=1592310338)

# %%
comfort=Counter('COMFORT','2127',scheduler_on=False)

# %%
comfort=Counter('COMFORT','2127')

# %%
print('test')

# %%
import pandas as pd
df_=pd.read_csv("./history/calculated_data/Technology/force/technology_force.csv")

# %%
# Out:
# 0       0138
# 1       0138
# 2       0138
# 3       0138
# 4       0138
#         ...
# 2239    8338
# 2240    8338
# 2241    8338
# 2242    8338
# 2243    8338
# Name: counter, Length: 2244, dtype: object

# %%
df_['counter']=df_['counter'].astype(str)
df_['counter']=df_['counter'].str.zfill(4)
df_[df_['counter']=='0138']
# Out:
#    symbol counter        date      force_sum      force_max     force_min  \
# 0    MYEG    0138  2020-06-18  112365.211242   25400.653595  -9892.903226
# 1    MYEG    0138  2020-06-17   54691.425280   22195.945946 -10046.258503
# 2    MYEG    0138  2020-06-16   45415.310708   14639.860140 -15568.055556
# 3    MYEG    0138  2020-06-15  -76575.638231    7934.782609 -61451.748252
# 4    MYEG    0138  2020-06-12   15892.559851   16142.068966 -54096.644295
# 5    MYEG    0138  2020-06-11  270546.110262  152266.216216 -40130.463576
# 6    MYEG    0138  2020-06-10  248987.681454   44513.178295 -13258.394161
# 7    MYEG    0138  2020-06-09   -2774.643593   15850.000000  -6331.200000
# 8    MYEG    0138  2020-06-07  -71532.602006    7070.731707 -13435.483871
# 9    MYEG    0138  2020-06-06  -71532.602006    7070.731707 -13435.483871
# 10   MYEG    0138  2020-06-05  -71532.602006    7070.731707 -13435.483871
# 11   MYEG    0138  2020-06-04  -33868.297865    3899.224806  -8512.977099
# 12   MYEG    0138  2020-06-03  -27732.135465    3436.923077  -8511.538462
# 13   MYEG    0138  2020-06-02   12910.802413   21764.885496 -16036.363636
# 14   MYEG    0138  2020-06-01   10071.867155    2885.496183  -5164.393939
# 15   MYEG    0138  2020-05-31  100279.849009   74800.000000  -5782.962963
# 16   MYEG    0138  2020-05-30  100279.849009   74800.000000  -5782.962963
# 17   MYEG    0138  2020-05-29  100279.849009   74800.000000  -5782.962963
# 18   MYEG    0138  2020-05-28   85733.386282   77926.618705 -49520.000000
# 19   MYEG    0138  2020-05-27  -56828.238949  108317.293233 -31333.333333
# 20   MYEG    0138  2020-05-24       0.000000       0.000000      0.000000
# 12          0.345168           3000.0          9.743664           21554.0
# 13          0.398614           5000.0         12.489168           16381.0
# 14          0.340270           5000.0         14.977490           14916.0
# 15          0.366648           5000.0          6.983086           21852.0
# 16          0.366648           5000.0          6.983086           21852.0
# 17          0.366648           5000.0          6.983086           21852.0
# 18          0.376676           5000.0          8.016172           43547.0
# 19          0.494753           5000.0         11.714948           53746.0
# 20          0.000000           2000.0         -4.737187            1710.0
# 21          0.000000           2000.0         -4.737187            1710.0
# 22          0.000000           2000.0         -4.737187            1710.0
# 23          0.290588           5000.0          6.947511           14220.0
# 24          0.336954           5000.0         23.701689           16418.0
# 25          0.401505           5000.0         18.312505           63861.0
# 26          0.290774           5000.0         27.715281           23917.0
# 27          0.312699           5000.0         12.043588           15993.0
# 28          0.312699           5000.0         12.043588           15993.0
# 29          0.312699           5000.0         12.043588           15993.0
# 30          0.332575           5000.0         13.037974           11250.0
# 31          0.308453           5000.0         19.118187           27954.0
# 32          0.337683           5000.0         23.434861           19397.0
# 33          0.308790           5000.0         39.545560           28726.0
# 34          0.308790           5000.0         39.545560           28726.0
# 35          0.308790           5000.0         39.545560           28726.0
# 36          0.289427           5000.0         38.893364           12199.0
# 37          0.313721           4289.0         13.242223           20356.0
# 38          0.300245           5000.0         31.825619           12208.0
# 39          0.355809           5000.0         23.335780           37147.0
# 40          0.401236           5000.0         12.074206           36802.0
# 41          0.349221           5000.0         32.232802           14576.0
# 42          0.273160           5000.0         25.167489           17645.0
# 43          0.332280           5000.0         16.116781           20979.0
# 44          0.406003           5000.0         15.155022           19581.0
# 45          0.336235           5000.0         31.511977           33320.0
# 46          0.470877           5000.0         21.309601           11845.0
# 47          0.425619           5000.0         14.862897           32764.0
# 48          0.367978           5000.0          9.180755           29565.0
# 49          0.451617           5000.0         24.836058           42089.0
# 50          0.443591           5000.0         36.177206           30576.0
# 51          0.225815           5000.0         11.229503           29099.0
# 52          0.189244           5000.0         29.654635           15201.0
# 53          0.171596           5000.0         14.427196           21208.0
# 54          0.243659           5000.0         -2.123844           23709.0
# 55          0.227888           5000.0          9.568396           20493.0
# 56          0.422738           5000.0         17.824909           41322.0
# 57          0.242449           5000.0          3.966170           27466.0
# 58          0.250234           5000.0         20.078630           13815.0
#
#     sell_vol_chg_mean
# 0           36.485499
# 1           47.658402
# 2           55.427143
# 3           31.904410
# 4           23.769903
# 5           37.211230
# 6           51.456807
# 7           22.433420
# 8           19.720942
# 9           19.720942
# 10          19.720942
# 11          63.719613
# 12          45.118580
# 13          28.696590
# 14          32.729901
# 15          21.638056
# 16          21.638056
# 17          21.638056
# 18          32.602458
# 19          42.467350
# 20          69.894730
# 21          69.894730
# 22          69.894730
# 23          27.484599
# 24          42.236787
# 25          51.622304
# 26          51.887679
# 27          25.636824
# 28          25.636824
# 29          25.636824
# 30          26.899280
# 31          45.049653
# 32          17.943971
# 33          46.917456
# 34          46.917456
# 35          46.917456
# 36          50.388948
# 37          31.731760
# 38          63.870295
# 39          55.978784
# 40          33.625879
# 41          40.675424
# 42          62.546470
# 43          44.741974
# 44          45.917103
# 45          30.586762
# 46          19.522483
# 47          56.387291
# 48          37.684816
# 49          70.232623
# 50          46.957823
# 51          35.513337
# 52          72.188413
# 53          45.565990
# 54          41.646459
# 55          50.988774
# 56          46.788424
# 57          54.829133
# 58          50.217380
